# %%
#Data Preparation
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df_iris = pd.DataFrame(iris.data,columns =iris.feature_names)
df_iris["species"] = iris.target
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df_iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
#Data Exploration and Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Histogram
plt.hist(df_iris["sepal length (cm)"],bins=10,color = "tan")
plt.xlabel("sepal length (cm)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Barplot
sns.barplot(x='species', y='sepal length (cm)', data=df_iris, palette='coolwarm')
plt.title('Average Sepal Length by Species')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16240\152100361.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species', y='sepal length (cm)', data=df_iris, palette='coolwarm')

# %%
#Boxplot
sns.boxplot(x='species', y='petal length (cm)', data=df_iris, palette='coolwarm')
plt.title('Petal Length Distribution by Species')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16240\1910717041.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal length (cm)', data=df_iris, palette='coolwarm')

# %%
#Violinplot
sns.violinplot(x='species', y='petal width (cm)', data=df_iris, palette='coolwarm')
plt.title('Sepal Length Distribution by Species')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16240\495742385.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='petal width (cm)', data=df_iris, palette='coolwarm')

# %%
#Histogram using seaborn
sns.histplot(df_iris["sepal length (cm)"],bins=10,kde=True,color = "red")
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
#Heatmap
corr_data = df_iris.corr()
sns.heatmap(corr_data,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#Pairplot
df_iris['species'] = df_iris['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
sns.pairplot(df_iris, hue='species', diag_kind='kde', markers=["o", "s", "D"])

# %%
#ScatterPlot
sns.scatterplot(x=df_iris["sepal length (cm)"],y=df_iris["petal length (cm)"],color = "purple")
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>

# %%
#Pie Diagram
species_counts = df_iris['species'].value_counts()
explode = (0.1,0,0)

# Plot pie chart
plt.pie(
    species_counts,
    explode = explode,
    labels=species_counts.index,
    autopct='%1.2f%%',
    startangle=90,
    colors=['skyblue', 'pink', 'lightgreen']
)
plt.title('Distribution of Iris Species')
plt.axis('equal')  
plt.show()

# %%
#Data Preprocessing
x = df_iris.iloc[:,:-1]
y = df_iris.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
xtrain.shape
# Out:
# (120, 4)

# %%
ytrain.shape
# Out:
# (120,)

# %%
xtest.shape
# Out:
# (30, 4)

# %%
ytest.shape
# Out:
# (30,)

# %%
#Model Selection and Training by Logistic Regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
predictions = lr.predict(xtest)
predictions
# Out:
# array(['setosa', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'virginica'],
#       dtype=object)

# %%
#Model Evaluation
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

# %%
accuracy_score(predictions,ytest)
# Out:
# 0.9666666666666667

# %%
precision_macro = precision_score(y_test, predictions, average='macro')
precision_weighted = precision_score(y_test, predictions, average='weighted')

print(f"Macro Precision: {precision_macro:.2f}")
print(f"Weighted Precision: {precision_weighted:.2f}")
# Out:
# Macro Precision: 0.95
# Weighted Precision: 0.97

# %%
recall_macro = recall_score(ytest, predictions, average='macro')
recall_weighted = recall_score(ytest, predictions, average='weighted')

print(f"Macro Recall: {recall_macro:.2f}")
print(f"Weighted Recall: {recall_weighted:.2f}")
# Out:
# Macro Recall: 0.97
# Weighted Recall: 0.97

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_matrix(predictions,ytest)
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  1,  6]], dtype=int64)

# %%
print(classification_report(predictions,ytest))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.92      1.00      0.96        12
#    virginica       1.00      0.86      0.92         7
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.95      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
#Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# %%
gridsearch = GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,n_jobs=-1,scoring="accuracy")
gridsearch
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 200]},
#              scoring='accuracy')

# %%
gridsearch.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 200]},
#              scoring='accuracy')

# %%
print(gridsearch.best_params_)
# Out:
# {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 10}

# %%
print(gridsearch.best_score_)
# Out:
# 0.9583333333333334

# %%
test_score = gridsearch.score(xtest, ytest)
print(f"Test Score: {test_score:.2f}")
# Out:
# Test Score: 0.97

# %%
#Model Interpretation and Insights(feature_importance)
importance = gridsearch.best_estimator_.feature_importances_

# %%
import numpy as np
indices = np.argsort(importance)[::-1]
features = iris.columns[:-1]
features
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
print("Feature Importance:")
for i in range(len(features)):
    print(f"{features[indices[i]]}: {importance[indices[i]]:.4f}")
# Out:
# Feature Importance:
# PetalLengthCm: 0.6926
# PetalWidthCm: 0.2275
# SepalWidthCm: 0.0402
# SepalLengthCm: 0.0398

# %%
#Model Interpretation and Insights(decision_boundary)
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# %%
# Train a Decision Tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train_encoded)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Create a mesh grid for the decision boundary
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# %%
# Predict the class for each point in the mesh grid
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.8, cmap='coolwarm')
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train_encoded, edgecolors='k', marker='o', s=100, cmap='coolwarm')
plt.title("Decision Tree Decision Boundary")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
